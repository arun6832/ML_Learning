# %% [markdown]
# ###### https://www.w3schools.com/python/python_ml_decision_tree.asp
# ##### Machine Learning Lab2: Created by Jibrael Jos,PhD
# ##### Topic: Decision Tree Explorations
# ##### Student Name: Ardra K S
# ##### Roll No: 23122109
# ##### Date: 7/03/2024
# ##### Submission : 10/03/2024
# ##### Python Notebook as PDF (File Name MLDecisionTree21.pdf)
# ##### and Observations in MLLab2_109.xlsx

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\arunp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\arunp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\arunp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# 1.Upload data from a csv file
df = pd.read_csv("dataTree1.csv")

print(df)
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES

# %%
# 2.Upload from a text file where seperator is tab
sample=pd.read_csv("sample.txt",sep=" ")
sample
# Out:
#         Month Product_Category Region  Advertising_Cost  Sales  Profit
# 0     January      Electronics  North              5000  15000    7000
# 1    February         Clothing  South              3000  12000    5500
# 2       March  Home_Appliances   West              4500  18000    8000
# 3       April      Electronics   East              5500  16000    7500
# 4         May         Clothing  North              4000  13000    6000
# 5        June  Home_Appliances  South              3500  14000    6500
# 6        July      Electronics   West              6000  17000    7800
# 7      August         Clothing   East              5000  16000    7200
# 8   September  Home_Appliances  North              4500  14000    6000
# 9     October      Electronics  South              3500  15000    6800
# 10   November         Clothing   West              4000  17000    7500
# 11   December  Home_Appliances   East              5500  18000    8200

# %%
# # 3.Upload from an Excel Sheet
# sample1 = pd.read_excel('sample2.xlsx')
# print(sample1)

# %%
# 4. Explore map function in a data frame
df = pd.read_csv("dataTree1.csv")
print(df)
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES

# %%
#changing UK as 1, USA as 2, N as 3

d={'UK':1,'USA':2,'N':3}
df['Nationality']=df['Nationality'].map(d)
df
# Out:
#     Age  Experience  Rank  Nationality   Go
# 0    36          10     9            1   NO
# 1    42          12     4            2   NO
# 2    23           4     6            3   NO
# 3    52           4     4            2   NO
# 4    43          21     8            2  YES
# 5    44          14     5            1   NO
# 6    66           3     7            3  YES
# 7    35          14     9            1  YES
# 8    52          13     7            3  YES
# 9    35           5     9            3  YES
# 10   24           3     5            2   NO
# 11   18           3     7            1  YES
# 12   45           9     9            1  YES

# %%
#changing NO as 0 and yes as 1
d={'YES':1,'NO':0}
df['Go']=df['Go'].map(d)
df
# Out:
#     Age  Experience  Rank  Nationality  Go
# 0    36          10     9            1   0
# 1    42          12     4            2   0
# 2    23           4     6            3   0
# 3    52           4     4            2   0
# 4    43          21     8            2   1
# 5    44          14     5            1   0
# 6    66           3     7            3   1
# 7    35          14     9            1   1
# 8    52          13     7            3   1
# 9    35           5     9            3   1
# 10   24           3     5            2   0
# 11   18           3     7            1   1
# 12   45           9     9            1   1

# %%
#Adding month column
df.insert(5,"month",["Jan","Feb","Mar","Jan","Feb","Mar","Jan","Feb","Mar","Jan","Feb","Mar","Feb"],True)
df
# Out:
#     Age  Experience  Rank  Nationality  Go month
# 0    36          10     9            1   0   Jan
# 1    42          12     4            2   0   Feb
# 2    23           4     6            3   0   Mar
# 3    52           4     4            2   0   Jan
# 4    43          21     8            2   1   Feb
# 5    44          14     5            1   0   Mar
# 6    66           3     7            3   1   Jan
# 7    35          14     9            1   1   Feb
# 8    52          13     7            3   1   Mar
# 9    35           5     9            3   1   Jan
# 10   24           3     5            2   0   Feb
# 11   18           3     7            1   1   Mar
# 12   45           9     9            1   1   Feb

# %%
d={'Jan':1,'Feb':2,'Mar':3}
df['month']=df['month'].map(d)
df
# Out:
#     Age  Experience  Rank  Nationality  Go  month
# 0    36          10     9            1   0      1
# 1    42          12     4            2   0      2
# 2    23           4     6            3   0      3
# 3    52           4     4            2   0      1
# 4    43          21     8            2   1      2
# 5    44          14     5            1   0      3
# 6    66           3     7            3   1      1
# 7    35          14     9            1   1      2
# 8    52          13     7            3   1      3
# 9    35           5     9            3   1      1
# 10   24           3     5            2   0      2
# 11   18           3     7            1   1      3
# 12   45           9     9            1   1      2

# %%
df.insert(6,"status",["True","False","True","True","False","True","True","False","True","True","False","True","False"])
df
# Out:
#     Age  Experience  Rank  Nationality  Go  month status
# 0    36          10     9            1   0      1   True
# 1    42          12     4            2   0      2  False
# 2    23           4     6            3   0      3   True
# 3    52           4     4            2   0      1   True
# 4    43          21     8            2   1      2  False
# 5    44          14     5            1   0      3   True
# 6    66           3     7            3   1      1   True
# 7    35          14     9            1   1      2  False
# 8    52          13     7            3   1      3   True
# 9    35           5     9            3   1      1   True
# 10   24           3     5            2   0      2  False
# 11   18           3     7            1   1      3   True
# 12   45           9     9            1   1      2  False

# %%
# 6. Create a map function to convert True to 1 and False to Zero
d={'True':1,'False':0}
df['status']=df['status'].map(d)
df
# Out:
#     Age  Experience  Rank  Nationality  Go  month  status
# 0    36          10     9            1   0      1       1
# 1    42          12     4            2   0      2       0
# 2    23           4     6            3   0      3       1
# 3    52           4     4            2   0      1       1
# 4    43          21     8            2   1      2       0
# 5    44          14     5            1   0      3       1
# 6    66           3     7            3   1      1       1
# 7    35          14     9            1   1      2       0
# 8    52          13     7            3   1      3       1
# 9    35           5     9            3   1      1       1
# 10   24           3     5            2   0      2       0
# 11   18           3     7            1   1      3       1
# 12   45           9     9            1   1      2       0

# %%
features = ['Age', 'Experience', 'Rank', 'Nationality']

X = df[features]
y = df['Go']

print(X)
print(" ")
print(y)
# Out:
#     Age  Experience  Rank  Nationality
# 0    36          10     9            1
# 1    42          12     4            2
# 2    23           4     6            3
# 3    52           4     4            2
# 4    43          21     8            2
# 5    44          14     5            1
# 6    66           3     7            3
# 7    35          14     9            1
# 8    52          13     7            3
# 9    35           5     9            3
# 10   24           3     5            2
# 11   18           3     7            1
# 12   45           9     9            1
#
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     1
# 9     1
# 10    0
# 11    1
# 12    1
# Name: Go, dtype: int64

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\arunp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\arunp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.24.1)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\arunp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\arunp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\arunp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\arunp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

df = pandas.read_csv("dataTree1.csv")

d = {'UK': 0, 'USA': 1, 'N': 2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES': 1, 'NO': 0}
df['Go'] = df['Go'].map(d)

features = ['Age', 'Experience', 'Rank', 'Nationality']
print(features)
X = df[features]
y = df['Go']

dtree = DecisionTreeClassifier(criterion='gini')
dtree = dtree.fit(X, y)

tree.plot_tree(dtree, feature_names=features)
# Out:
# ['Age', 'Experience', 'Rank', 'Nationality']
# [Text(0.3333333333333333, 0.875, 'Rank <= 6.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.16666666666666666, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5, 0.625, 'Experience <= 9.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6666666666666666, 0.375, 'Experience <= 11.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8333333333333334, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
# 9. Change Gini to Entropy anc check calculation

dtree = DecisionTreeClassifier(criterion='entropy')
dtree = dtree.fit(X, y)

tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.4, 0.875, 'Rank <= 6.5\nentropy = 0.996\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.2, 0.625, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6, 0.625, 'Age <= 39.5\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.4, 0.375, 'Age <= 35.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2, 0.125, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.375, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]')]

# %%
# 10. Change different parameters and study the impact
dtree = DecisionTreeClassifier(criterion='gini',splitter='best')
dtree = dtree.fit(X, y)

tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.4, 0.9, 'Rank <= 6.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.2, 0.7, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6, 0.7, 'Nationality <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.4, 0.5, 'Age <= 35.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6, 0.3, 'Experience <= 9.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]')]

# %%
# 10. Change different parameters and study the impact
dtree = DecisionTreeClassifier(criterion='gini',splitter='random')
dtree = dtree.fit(X, y)

tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.3333333333333333, 0.9166666666666666, 'Rank <= 6.497\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.16666666666666666, 0.75, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5, 0.75, 'Rank <= 8.495\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.3333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6666666666666666, 0.5833333333333334, 'Nationality <= 1.708\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5, 0.4166666666666667, 'Experience <= 9.764\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3333333333333333, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.25, 'Experience <= 13.872\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8333333333333334, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8333333333333334, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
#Predicting the value of Go based on different values of the features
print(dtree.predict([[47, 12, 4, 0]]))
print(dtree.predict([[40, 10, 6, 1]]))
# Out:
# [0]
# [0]
# C:\Users\arunp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\arunp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\arunp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.20.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\arunp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Import the necessary libraries
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from graphviz import Source

# Load the dataset
iris = load_iris()
X = iris.data[:, 2:] # petal length and width
y = iris.target
features = ['Length', 'Width']
# DecisionTreeClassifier
tree_clf = DecisionTreeClassifier(criterion='entropy',
								max_depth=2)
tree_clf.fit(X, y)
tree.plot_tree(tree_clf, feature_names=features)
# Out:
# [Text(0.4, 0.8333333333333334, 'Width <= 0.8\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.6, 0.5, 'Width <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.4, 0.16666666666666666, 'entropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.8, 0.16666666666666666, 'entropy = 0.151\nsamples = 46\nvalue = [0, 1, 45]')]

# %%
from sklearn.datasets import load_sample_images

# %%
tree_clf = DecisionTreeClassifier(criterion='gini',
								max_depth=2)
tree_clf.fit(X, y)
tree.plot_tree(tree_clf, feature_names=features)
# Out:
# [Text(0.4, 0.8333333333333334, 'Width <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.6, 0.5, 'Width <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]')]

# %% [markdown]
# 13. Read about Decision Tree (share URL read).
#
# https://www.javatpoint.com/machine-learning-decision-tree-classification-algorithm
#
# https://scikit-learn.org/stable/modules/tree.html

# %% [markdown]
# ### Identify advantages and disadvantages
#
# #### Advantages
# --> Trees can be visulaised. So it is simple to understand and interpret
# --> Does not require complex data preperation like normalisation or omitting NA values.
# --> Able to handle both numerical and categorical data.
# --> Able to handle multi-output problems.
# --> Possible to validate a model using statistical tests. That makes it possible to account for the reliability of the model.
#
# #### Disadvantages
#
# --> Decision trees can be unstable because small variations in the data might result in a completely different tree being generated. This problem is mitigated by using decision trees within an ensemble.
#
# --> Predictions of decision trees are neither smooth nor continuous, but piecewise constant approximations as seen in the above figure. Therefore, they are not good at extrapolation.
#
# --> Decision tree learners create biased trees if some classes dominate. It is therefore recommended to balance the dataset prior to fitting with the decision tree.
#
# --> Decision-tree learners can create over-complex trees that do not generalize the data well. This is called overfitting. Mechanisms such as pruning, setting the minimum number of samples required at a leaf node or setting the maximum depth of the tree are necessary to avoid this problem.

# %% [markdown]
# #### 14. Watch a video on Decision Tree(share URL)
# https://youtu.be/_L39rN6gz7Y?feature=shared
