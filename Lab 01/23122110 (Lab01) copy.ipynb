# %% [markdown]
# Name : Arun M
# Register No : 23122110
# Class : 3MScDS B

# %% [markdown]
# A. Data Exploration and Preprocessing

# %%
import pandas as pd
# Load the California housing dataset
# Create a DataFrame from the dataset using the data and feature names
df = pd.read_csv("housing.csv")

# Print the DataFrame to view the data
print(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  ocean_proximity  price
# 0             322         126         8.3252                0    2.0
# 1            2401        1138         8.3014                0    2.0
# 2             496         177         7.2574                0    2.0
# 3             558         219         5.6431                0    2.0
# 4             565         259         3.8462                0    2.0
# ...           ...         ...            ...              ...    ...
# 20635         845         330         1.5603                2    0.0
# 20636         356         114         2.5568                2    0.0
# 20637        1007         433         1.7000                2    0.0
# 20638         741         349         1.8672                2    0.0
# 20639        1387         530         2.3886                2    0.0
#
# [20640 rows x 10 columns]

# %%
#Finding the First five Rows
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  ocean_proximity  price
# 0         322         126         8.3252                0    2.0
# 1        2401        1138         8.3014                0    2.0
# 2         496         177         7.2574                0    2.0
# 3         558         219         5.6431                0    2.0
# 4         565         259         3.8462                0    2.0

# %%
#Finding the descriptive Statistics of the All Vaiables
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        ocean_proximity         price
# count     20640.000000  20575.000000
# mean          1.464729      1.451859
# std           0.854226      0.776717
# min           0.000000      0.000000
# 25%           1.000000      1.000000
# 50%           1.000000      2.000000
# 75%           2.000000      2.000000
# max           4.000000      2.000000

# %%
#DataTypes of the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  int64
#  9   price               20575 non-null  float64
# dtypes: float64(5), int64(5)
# memory usage: 1.6 MB

# %%
#Descriptive Statistics of All Features including all Categorical Variables
df.describe(include="all")
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        ocean_proximity         price
# count     20640.000000  20575.000000
# mean          1.464729      1.451859
# std           0.854226      0.776717
# min           0.000000      0.000000
# 25%           1.000000      1.000000
# 50%           1.000000      2.000000
# 75%           2.000000      2.000000
# max           4.000000      2.000000

# %%
# #Checking is there any Missing Values 
# missing=df.dropna(inplace = True)
# print(missing)

# %%
#Checking for Duplicate Values
dup=df.drop_duplicates(inplace = True)
print(dup)
# Out:
# None

# %%
#Checking the Null Values in the Dataset
null_counts = df.isnull().sum()
print("Null values in each column:")
print(null_counts)
# Out:
# Null values in each column:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# price                  65
# dtype: int64

# %%
df=df.dropna()

# %%
from sklearn.preprocessing import StandardScaler

# Standardization using StandardScaler
scaler_standard = StandardScaler()
standardized_data = scaler_standard.fit_transform(df)
standardized_df = pd.DataFrame(standardized_data, columns=df.columns)

# %%
#Histogram of all Features 
import matplotlib.pyplot as plt

df.hist(figsize=(12,10),bins=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# B. Model Building

# %%
#Finding the Correlation to Extract the Best Input Variables
corr=df.corr()
corr
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924516           -0.109647     0.045255
# latitude            -0.924516  1.000000            0.012340    -0.036674
# housing_median_age  -0.109647  0.012340            1.000000    -0.360317
# total_rooms          0.045255 -0.036674           -0.360317     1.000000
# total_bedrooms       0.069291 -0.066841           -0.320408     0.930335
# population           0.099791 -0.108550           -0.295824     0.857732
# households           0.056311 -0.071709           -0.302623     0.919129
# median_income       -0.015237 -0.080301           -0.117884     0.198192
# ocean_proximity      0.180433 -0.067065           -0.205892     0.016123
# price                0.030393 -0.236979            0.033008     0.135594
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069291    0.099791    0.056311      -0.015237
# latitude                 -0.066841   -0.108550   -0.071709      -0.080301
# housing_median_age       -0.320408   -0.295824   -0.302623      -0.117884
# total_rooms               0.930335    0.857732    0.919129       0.198192
# total_bedrooms            1.000000    0.878095    0.979903      -0.007432
# population                0.878095    1.000000    0.907283       0.005416
# households                0.979903    0.907283    1.000000       0.013691
# median_income            -0.007432    0.005416    0.013691       1.000000
# ocean_proximity           0.004437   -0.006531   -0.015158      -0.130020
# price                     0.092325    0.065020    0.113254       0.489468
#
#                     ocean_proximity     price
# longitude                  0.180433  0.030393
# latitude                  -0.067065 -0.236979
# housing_median_age        -0.205892  0.033008
# total_rooms                0.016123  0.135594
# total_bedrooms             0.004437  0.092325
# population                -0.006531  0.065020
# households                -0.015158  0.113254
# median_income             -0.130020  0.489468
# ocean_proximity            1.000000 -0.279108
# price                     -0.279108  1.000000

# %%
import seaborn as sns
sns.heatmap(corr,annot=True,cmap='magma')
# Out:
# <Axes: >

# %%
#Feature Selection 
import numpy as np
x=np.array(df)
Y=x[:,9]
x=x[:,0:8]

# %%
#Splitting the Dataset into Training and Testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,Y,random_state=42,test_size=0.25)

# %%
#Fitting the Dataset into Liner Regression Model
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(criterion='gini')
dtree = dtree.fit(x, Y)

# %%
import matplotlib.pyplot as plt
from sklearn import tree

tree.plot_tree(dtree, feature_names=x)
print(X_train.shape)
# Out:
# (15277, 8)

# %%
#Predicting the X_test
y_pred = dtree.predict(X_test)
print(y_pred)
# Out:
# [2. 1. 2. ... 2. 2. 2.]

# %%
from sklearn.metrics import accuracy_score
y_pred = dtree.predict(X_test)
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
from sklearn.svm import SVC 
clf = SVC(kernel='poly') 

# fitting x samples and y classes 
clf.fit(x, Y)
# Out:
# SVC(kernel='poly')

# %%
#Predicting the X_test
y_pred = clf.predict(X_test)
print(y_pred)
# Out:
# [2. 2. 2. ... 2. 2. 2.]

# %%
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X_test)
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6218338896524641
